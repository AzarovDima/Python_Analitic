# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./laptops_10.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   Product        1303 non-null   object
#  2   TypeName       1303 non-null   object
#  3   Inches         1303 non-null   float64
#  4   Cpu            1303 non-null   object
#  5   Ram            1303 non-null   object
#  6   Gpu            1303 non-null   object
#  7   OpSys          1303 non-null   object
#  8   Weight         1303 non-null   float64
#  9   Price_euros    1303 non-null   float64
#  10  Cpu_Company    1303 non-null   object
#  11  Memory_Amount  1303 non-null   int64
#  12  Memory_Type    1303 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.5+ KB

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
# ...

# %% [markdown]
# 1.1 Изучите количество памяти с помощью matplotlib<br>
# 1.2 Изучите стоимость ноутбуков с помощью matplotlib<br>
# 1.3 Изучите вес ноутбуков с помощью matplotlib<br>
# Постройте график<br>
# Назовите график<br>
# Сделайте именование оси x и оси y<br>
# Сделайте выводы<br>

# %%
plt.figure(figsize=(6, 4))

sns.histplot(df['Memory_Amount'], bins=10)

plt.title('Kоличество памяти в ноутбуке')
plt.xlabel('Объем памяти')
plt.ylabel('Кол-во ноутбуков');

# %%
df['Memory_Amount'].value_counts()
# Out:
# 256     508
# 1024    250
# 128     177
# 512     140
# 500     132
# 32       45
# 64       17
# 2048     16
# 16       10
# 180       5
# 240       1
# 8         1
# 508       1
# Name: Memory_Amount, dtype: int64

# %%
plt.figure(figsize=(6, 4))

plt.hist(df['Memory_Amount'], bins=10)

plt.title('Kоличество памяти в ноутбуке')
plt.xlabel('Объем памяти')
plt.ylabel('Кол-во ноутбуков');

# %%
df['Price_euros'].nunique()
# Out:
# 791

# %%
plt.figure(figsize=(6, 6))

plt.hist(df['Price_euros'], bins=100, orientation='horizontal')

plt.title('Стоимость ноутбуке')
plt.xlabel('Стоимость')
plt.ylabel('Кол-во ноутбуков');

# %%
plt.figure(figsize=(8, 4))

sns.histplot(df['Weight'], bins=25)

plt.title('Вес ноутбуков')
plt.xlabel('Вес ноутбуков')
plt.ylabel('Кол-во ноутбуков');

# %%
df['Weight'].value_counts()
# Out:
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: Weight, Length: 171, dtype: int64

# %% [markdown]
# 2.1 Изучите распределение типов носителя

# %%
data_1 = df['Memory_Type'].value_counts()
names = data_1.index
values = data_1.values

# %%
df['Memory_Type'].value_counts()
# Out:
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: Memory_Type, dtype: int64

# %%
plt.figure(figsize=(10, 8))
plt.pie(values, autopct='%1.1f%%', labels=names)
plt.title('Доля типов носителей')
plt.legend(names, loc='upper left');

# %%
plt.figure(figsize=(6, 4))

plt.bar(data_1.index, data_1.values)

plt.title('Типы носителя')
plt.xlabel('Типы носителя')
plt.ylabel('Кол-во')
plt.xticks(rotation=30);

# %% [markdown]
# 2.2 Изучите распределение компаний производителей

# %%
data_2 = df['Company'].value_counts()
data_2
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
plt.figure(figsize=(12, 4))

plt.bar(data_2.index, data_2.values)

plt.title('Компании')
plt.xlabel('Название компаний')
plt.ylabel('Кол-во')
plt.xticks(rotation=30);

# %% [markdown]
# 2.3 Изучите распределение операционной системы

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %%
data_3 = df['OpSys'].value_counts()
data_3
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
plt.figure(figsize=(6, 4))

plt.bar(data_3.index, data_3.values)

plt.title('Операционная система')
plt.xlabel('Название OpSys')
plt.ylabel('Кол-во')
plt.xticks(rotation=30);

# %%
plt.figure(figsize=(10, 10))
expl = [0.2, 0.03, 0.04, 0.05, 0.07, 0.06, 0.05, 0.04, 0.5]
plt.pie(data_3.values, autopct='%1.1f%%', labels=data_3.index, explode=expl)
plt.title('Доля типов носителей')
plt.legend(data_3.index, loc='best');

# %% [markdown]
# 2.4 Изучите распределение компаний производителей CPU

# %%
data_4 = df['Cpu_Company'].value_counts()
data_4
# Out:
# Intel      1240
# AMD          62
# Samsung       1
# Name: Cpu_Company, dtype: int64

# %%
plt.figure(figsize=(6, 4))

plt.bar(data_4.index, data_4.values)

plt.title('Cpu_Company')
plt.xlabel('Название Cpu_Company')
plt.ylabel('Кол-во')
plt.xticks(rotation=30);

# %%
plt.figure(figsize=(5, 5))
explode = [0.5, 0.3, 0.7]
plt.pie(data_4.values, autopct='%1.1f%%', labels=data_4.index, explode=explode, colors = ["0.9", "r", "#000080",])
plt.title('Распределение компаний производителей CPU')
plt.legend(data_4.index, loc='best');

# %% [markdown]
# Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму
# Процессоры от Samsung не изучайте

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %%
# Company # Cpu

# %%
plt.figure(figsize=(18, 9))

sns.boxplot(x=df['Price_euros'], y=df["Cpu_Company"], whis=1.5)

plt.xlabel('Price_euros')
plt.show()

# %%
data_5 = pd.crosstab(df['Company'], df['Cpu_Company']).reset_index()
data_5
# Out:
# Cpu_Company    Company  AMD  Intel  Samsung
# 0                 Acer   10     93        0
# 1                Apple    0     21        0
# 2                 Asus   11    147        0
# 3                Chuwi    0      3        0
# 4                 Dell    0    297        0
# 5              Fujitsu    0      3        0
# 6               Google    0      3        0
# 7                   HP   25    249        0
# 8               Huawei    0      2        0
# 9                   LG    0      3        0
# 10              Lenovo   16    281        0
# 11                 MSI    0     54        0
# 12            Mediacom    0      7        0
# 13           Microsoft    0      6        0
# 14               Razer    0      7        0
# 15             Samsung    0      8        1
# 16             Toshiba    0     48        0
# 17                Vero    0      4        0
# 18              Xiaomi    0      4        0

# %%
data_5.drop('Samsung', axis=1, inplace=True)

# %%
data_5['Company']
# Out:
# 0          Acer
# 1         Apple
# 2          Asus
# 3         Chuwi
# 4          Dell
# 5       Fujitsu
# 6        Google
# 7            HP
# 8        Huawei
# 9            LG
# 10       Lenovo
# 11          MSI
# 12     Mediacom
# 13    Microsoft
# 14        Razer
# 15      Samsung
# 16      Toshiba
# 17         Vero
# 18       Xiaomi
# Name: Company, dtype: object

# %%
data_5
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
plt.figure(figsize=(8, 6))

# определяем кол-во делений
n_ticks = np.arange(len(data_5['Intel']))

# определяем сдвиг
offset = 0.2

# определяем ширину столбцов
w = 0.4

# добавляем сдвиг к кол-ву делений
plt.bar(n_ticks - offset, data_5['Intel'], width=w)
plt.bar(n_ticks + offset, data_5['AMD'], width=w)

plt.title('Взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров')
plt.xlabel('Производители ноутбуков')
plt.ylabel('Кол-во')
plt.legend(['Intel', 'AMD'])
plt.xticks(n_ticks, data_5['Company'], rotation = 30);  # добавляем метки делений

# %%
df_company_process = pd.crosstab(df['Company'], df['Cpu_Company'])
df_company_process.drop('Samsung', axis=1, inplace = True)
plt.bar(df_company_process.index,df_company_process['AMD'], color='green')
plt.bar(df_company_process.index,df_company_process['Intel'], bottom = df_company_process['AMD'])

plt.xticks(rotation = 45);

# %%
data_6 = pd.crosstab(df['Company'], df['Cpu_Company'], normalize='index').reset_index()
data_6
# Out:
# Cpu_Company    Company       AMD     Intel   Samsung
# 0                 Acer  0.097087  0.902913  0.000000
# 1                Apple  0.000000  1.000000  0.000000
# 2                 Asus  0.069620  0.930380  0.000000
# 3                Chuwi  0.000000  1.000000  0.000000
# 4                 Dell  0.000000  1.000000  0.000000
# 5              Fujitsu  0.000000  1.000000  0.000000
# 6               Google  0.000000  1.000000  0.000000
# 7                   HP  0.091241  0.908759  0.000000
# 8               Huawei  0.000000  1.000000  0.000000
# 9                   LG  0.000000  1.000000  0.000000
# 10              Lenovo  0.053872  0.946128  0.000000
# 11                 MSI  0.000000  1.000000  0.000000
# 12            Mediacom  0.000000  1.000000  0.000000
# 13           Microsoft  0.000000  1.000000  0.000000
# 14               Razer  0.000000  1.000000  0.000000
# 15             Samsung  0.000000  0.888889  0.111111
# 16             Toshiba  0.000000  1.000000  0.000000
# ...

# %%
data_6.drop('Samsung', axis=1, inplace=True)
data_6
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Samsung  0.000000  0.888889
# 16             Toshiba  0.000000  1.000000
# 17                Vero  0.000000  1.000000
# 18              Xiaomi  0.000000  1.000000

# %%
plt.bar(data_6['Company'], data_6['AMD'], color='red')
plt.bar(data_6['Company'], data_6['Intel'], bottom = data_6['AMD'])

plt.xticks(rotation = 45);

# %% [markdown]
# 4.1 Изучите взаимосвязь стоимости ноутбука и компании производителя процессора

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %%
# Cpu_Company Price_euros

# %%
plt.figure(figsize=(18, 9))

sns.boxplot(x=df['Price_euros'], y=df["Cpu_Company"], whis=1.5)

plt.xlabel('Price_euros')
plt.show()

# %% [markdown]
# 4.2 Изучите взаимосвязь стоимости ноутбука и типа носителя памяти

# %%
plt.figure(figsize=(18, 9))

sns.violinplot(x=df['Price_euros'], y=df["Memory_Type"])

plt.xlabel('Price_euros')
plt.show()

# %%
plt.figure(figsize=(18, 9))

sns.boxplot(x=df['Price_euros'], y=df["Memory_Type"])

plt.xlabel('Price_euros')
plt.show()

# %% [markdown]
# 4.3 Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти

# %%
plt.figure(figsize=(18, 9))

sns.boxplot(x=df['Price_euros'], y=df["Ram"])

plt.xlabel('Price_euros')
plt.show()

# %% [markdown]
# 4.4 Изучите взаимосвязь стоимости ноутбука и компании производителя

# %%
plt.figure(figsize=(18, 9))

sns.boxplot(x=df['Price_euros'], y=df["Company"])

plt.xlabel('Price_euros')
plt.show()

# %%
df[(df['Company'] == 'Samsung') & (df['Price_euros'] < 1000)]
# Out:
#       Company          Product            TypeName  Inches  \
# 430   Samsung     Chromebook 3             Netbook    11.6
# 1191  Samsung  Chromebook Plus  2 in 1 Convertible    12.3
#
#                                        Cpu  Ram                    Gpu  \
# 430   Intel Celeron Dual Core N3060 1.6GHz  4GB  Intel HD Graphics 400
# 1191         Samsung Cortex A72&A53 2.0GHz  4GB      ARM Mali T860 MP4
#
#           OpSys  Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type
# 430   Chrome OS    1.15        269.0       Intel             16  FlashStorage
# 1191  Chrome OS    1.15        659.0     Samsung             32  FlashStorage

# %%
df[(df['Company'] == 'Vero')].to_excel('Dataset_Vero.xlsx', index=False)

# %%
data_10 = pd.read_excel('./Dataset_Vero.xlsx')

# %%
data_10
# Out:
#   Company                           Product  TypeName  Inches  \
# 0    Vero     K147 (N3350/4GB/32GB/FHD/W10)  Notebook    14.0
# 1    Vero         K146 (N3350/4GB/32GB/W10)  Notebook    14.0
# 2    Vero      V142 (X5-Z8350/2GB/32GB/W10)  Notebook    14.0
# 3    Vero  V131 (X5-Z8350/4GB/32GB/FHD/W10)  Notebook    13.3
#
#                                     Cpu  Ram                    Gpu  \
# 0  Intel Celeron Dual Core N3350 1.1GHz  4GB  Intel HD Graphics 500
# 1  Intel Celeron Dual Core N3350 1.1GHz  4GB  Intel HD Graphics 500
# 2           Intel Atom X5-Z8350 1.44GHz  2GB  Intel HD Graphics 400
# 3           Intel Atom X5-Z8350 1.44GHz  4GB  Intel HD Graphics 400
#
#         OpSys  Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type
# 0  Windows 10    1.30        260.0       Intel             32  FlashStorage
# 1  Windows 10    1.22        202.9       Intel             32  FlashStorage
# 2  Windows 10    1.45        210.8       Intel             32  FlashStorage
# ...
