# %% [markdown]
# 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU <br>
# 1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя<br>
# 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD/SDD/др.)<br>
# 1.4 Удалите признаки Memory и ScreenResolution<br>

# %%
import pandas as pd

# %%
df = pd.read_csv('./laptop_price.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['Cpu_Company'] = df['Gpu'].apply(lambda x: x.split()[0])
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
def get_mem(full_mem):
    new_mem = full_mem.split()[0]
    unit = new_mem[-2:]
    if unit == 'GB':
        new_mem = float(new_mem.replace('GB', ''))
    else:
        new_mem = float(new_mem.replace('TB', ''))*1024
    return int(new_mem)

df['Memory_Amount'] = df['Memory'].apply(get_mem)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['Memory_Amount'].value_counts()
# Out:
# 256     508
# 1024    250
# 128     177
# 512     140
# 500     132
# 32       45
# 64       17
# 2048     16
# 16       10
# 180       5
# 240       1
# 8         1
# 508       1
# Name: Memory_Amount, dtype: int64

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory_Type'] = df['Memory'].apply(lambda x: x.split('B ')[-1])
df['Memory_Type'].value_counts()
# Out:
# SSD              641
# HDD              576
# Flash Storage     74
# Hybrid            12
# Name: Memory_Type, dtype: int64

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type
# 0  1.37kg      1339.69       Intel            128            SSD
# 1  1.34kg       898.94       Intel            128  Flash Storage
# ...

# %% [markdown]
# 2.1 Создайте признак SSD, который изначально равен 0<br>
# 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD<br>
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный<br>

# %%
df['SSD'] = 0

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0  1.37kg      1339.69       Intel            128            SSD    0
# ...

# %%
df['Memory_Type'].unique()
# Out:
# array(['SSD', 'Flash Storage', 'HDD', 'Hybrid'], dtype=object)

# %%
df.loc[df['Memory_Type'] == 'SSD','SSD'] = 1
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0  1.37kg      1339.69       Intel            128            SSD    1
# ...

# %% [markdown]
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   laptop_ID      1303 non-null   int64
#  1   Company        1303 non-null   object
#  2   Product        1303 non-null   object
#  3   TypeName       1303 non-null   object
#  4   Inches         1303 non-null   float64
#  5   Cpu            1303 non-null   object
#  6   Ram            1303 non-null   object
#  7   Gpu            1303 non-null   object
#  8   OpSys          1303 non-null   object
#  9   Weight         1303 non-null   object
#  10  Price_euros    1303 non-null   float64
#  11  Cpu_Company    1303 non-null   object
#  12  Memory_Amount  1303 non-null   int64
#  13  Memory_Type    1303 non-null   object
#  14  SSD            1303 non-null   int64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 152.8+ KB

# %%
df['Weight'] = df['Weight'].apply(lambda x: x.replace('kg', ''))

# %%
df['Weight'] = df['Weight'].astype('float')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel            128            SSD    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   laptop_ID      1303 non-null   int64
#  1   Company        1303 non-null   object
#  2   Product        1303 non-null   object
#  3   TypeName       1303 non-null   object
#  4   Inches         1303 non-null   float64
#  5   Cpu            1303 non-null   object
#  6   Ram            1303 non-null   object
#  7   Gpu            1303 non-null   object
#  8   OpSys          1303 non-null   object
#  9   Weight         1303 non-null   float64
#  10  Price_euros    1303 non-null   float64
#  11  Cpu_Company    1303 non-null   object
#  12  Memory_Amount  1303 non-null   int64
#  13  Memory_Type    1303 non-null   object
#  14  SSD            1303 non-null   int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 152.8+ KB

# %% [markdown]
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
# laptop_id - это индексы датафрейма с ноутбуками
# 3.1 Присоедините к таблице clients данные по ноутбукам через метод join
# 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
clients_id = clients.set_index('laptop_id')
df_id = df.set_index('laptop_ID')

# %%
clients_id.join(df_id)
# Out:
#            client_id Company            Product  TypeName  Inches  \
# laptop_id
# 506               45  Lenovo      ThinkPad L570  Notebook    15.6
# 398               32     NaN                NaN       NaN     NaN
# 710               67  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120               33    Dell      Inspiron 7570  Notebook    15.6
# 1999              43     NaN                NaN       NaN     NaN
#
#                                    Cpu  Ram                    Gpu  \
# laptop_id
# 506         Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 398                                NaN  NaN                    NaN
# 710        AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 120         Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
# 1999                               NaN  NaN                    NaN
#
#                 OpSys  Weight  Price_euros Cpu_Company  Memory_Amount  \
# laptop_id
# ...

# %%
df_id.join(clients_id)#.info()
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   laptop_ID      1303 non-null   int64
#  1   Company        1303 non-null   object
#  2   Product        1303 non-null   object
#  3   TypeName       1303 non-null   object
#  4   Inches         1303 non-null   float64
#  5   Cpu            1303 non-null   object
#  6   Ram            1303 non-null   object
#  7   Gpu            1303 non-null   object
#  8   OpSys          1303 non-null   object
#  9   Weight         1303 non-null   float64
#  10  Price_euros    1303 non-null   float64
#  11  Cpu_Company    1303 non-null   object
#  12  Memory_Amount  1303 non-null   int64
#  13  Memory_Type    1303 non-null   object
#  14  SSD            1303 non-null   int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 152.8+ KB

# %%
clients.merge(df, left_on='laptop_id', right_on='laptop_ID', how = 'inner')
# Out:
#    client_id  laptop_id  laptop_ID Company            Product  TypeName  \
# 0         45        506        506  Lenovo      ThinkPad L570  Notebook
# 1         67        710        710  Lenovo  IdeaPad 320-15ABR  Notebook
# 2         33        120        120    Dell      Inspiron 7570  Notebook
#
#    Inches                          Cpu  Ram                    Gpu  \
# 0    15.6   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 1    15.6  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 2    15.6   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
#
#         OpSys  Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0  Windows 10    2.30       911.00       Intel            256         SSD    1
# 1  Windows 10    2.20       429.00         AMD           1024         HDD    0
# 2  Windows 10    2.16      1130.33      Nvidia            256         HDD    0

# %% [markdown]
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
# Отсортируйте от меньшей стоимости к большей

# %%
df.groupby('Company').agg({'Price_euros': ['mean', 'max']})#.sort_values('Price_euros', ascending=True)
# Out:
#            Price_euros
#                   mean      max
# Company
# Acer        626.775825  2599.00
# Apple      1564.198571  2858.00
# Asus       1104.169367  3975.00
# Chuwi       314.296667   449.00
# Dell       1186.068990  3659.40
# Fujitsu     729.000000   799.00
# Google     1677.666667  2199.00
# HP         1067.774854  4389.00
# Huawei     1424.000000  1499.00
# LG         2099.000000  2299.00
# Lenovo     1086.384444  4899.00
# MSI        1728.908148  2799.00
# Mediacom    295.000000   389.00
# Microsoft  1612.308333  2589.00
# Razer      3346.142857  6099.00
# Samsung    1413.444444  1849.00
# Toshiba    1267.812500  2799.00
# Vero        217.425000   260.00
# Xiaomi     1133.462500  1399.95

# %% [markdown]
# 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['min', 'mean', 'max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   775.647667  2899.0
# ARM               659.0   659.000000   659.0
# Intel             174.0  1008.225582  3100.0
# Nvidia            459.0  1489.874250  6099.0

# %% [markdown]
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ

# %%
df.pivot_table(index = 'Ram',
               columns = 'Cpu_Company',
               aggfunc='count',
               values = 'Memory_Type',
               )
# Out:
# Cpu_Company   AMD  ARM  Intel  Nvidia
# Ram
# 12GB          3.0  NaN   10.0    12.0
# 16GB         17.0  NaN   52.0   131.0
# 24GB          NaN  NaN    1.0     2.0
# 2GB           1.0  NaN   21.0     NaN
# 32GB          NaN  NaN    1.0    16.0
# 4GB          62.0  1.0  281.0    31.0
# 64GB          NaN  NaN    NaN     1.0
# 6GB          19.0  NaN   11.0    11.0
# 8GB          78.0  NaN  345.0   196.0

# %% [markdown]
# 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount    Memory_Type  SSD
# 0    1.37      1339.69       Intel            128            SSD    1
# ...

# %%
df.pivot_table(index='OpSys',
               columns= 'Memory_Amount',
               aggfunc= 'mean',
               values= 'Price_euros',
               fill_value= '_'
              )
# Out:
# Memory_Amount    8       16          32          64           128     180   \
# OpSys
# Android             _       _           _       434.0            _       _
# Chrome OS           _  305.38  412.454545  774.333333       1275.0       _
# Linux               _       _           _           _       742.25       _
# Mac OS X            _       _           _           _       1099.0       _
# No OS               _       _           _           _       562.14       _
# Windows 10     2249.0       _  270.001471     499.716  1026.489167  1073.5
# Windows 10 S        _       _           _     308.995       1039.0       _
# Windows 7           _       _           _           _  1320.323333  1199.0
# macOS               _       _           _           _     1119.315       _
#
# Memory_Amount    240          256         500     508          512   \
# OpSys
# Android             _            _           _       _            _
# ...

# %%
pd.crosstab(
    index=df['OpSys'],
    columns=df['Memory_Amount'], 
    aggfunc='mean',
    values=df['Price_euros'],
    ).fillna('--')
# Out:
# Memory_Amount    8       16          32          64           128     180   \
# OpSys
# Android            --      --          --       434.0           --      --
# Chrome OS          --  305.38  412.454545  774.333333       1275.0      --
# Linux              --      --          --          --       742.25      --
# Mac OS X           --      --          --          --       1099.0      --
# No OS              --      --          --          --       562.14      --
# Windows 10     2249.0      --  270.001471     499.716  1026.489167  1073.5
# Windows 10 S       --      --          --     308.995       1039.0      --
# Windows 7          --      --          --          --  1320.323333  1199.0
# macOS              --      --          --          --     1119.315      --
#
# Memory_Amount    240          256         500     508          512   \
# OpSys
# Android            --           --          --      --           --
# ...

# %% [markdown]
# 5.1 Ноутбуков каких компаний и с каким процессором больше?

# %%
pd.crosstab(
    index=df['Company'],
    columns=df['Cpu_Company'], 
    ).max()
# Out:
# Cpu_Company
# AMD        77
# ARM         1
# Intel     182
# Nvidia     84
# dtype: int64

# %% [markdown]
# 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index= df['Memory_Type'],
            columns= df['Memory_Amount']

).max()
# Out:
# Memory_Amount
# 8         1
# 16        7
# 32       38
# 64       15
# 128      97
# 180       5
# 240       1
# 256     414
# 500     132
# 508       1
# 512     120
# 1024    227
# 2048     16
# dtype: int64
